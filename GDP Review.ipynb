# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel(r'GDP.xlsx')

# %%
df.head(10)
# Out:
#    Unnamed: 0   Country Name  Year  GDP (current US$)  \
# 0          33  United States  1991      6158129000000
# 1          34  United States  1992      6520327000000
# 2          35  United States  1993      6858559000000
# 3          36  United States  1994      7287236000000
# 4          37  United States  1995      7639749000000
# 5          38  United States  1996      8073122000000
# 6          39  United States  1997      8577554457000
# 7          40  United States  1998      9062818202000
# 8          41  United States  1999      9631174489000
# 9          42  United States  2000     10250947997000
#
#    GDP, PPP (current international $)  GDP per capita (current US$)  \
# 0                        6.158129e+12                  24342.258905
# 1                        6.520327e+12                  25418.990776
# 2                        6.858559e+12                  26387.293734
# 3                        7.287236e+12                  27694.853416
# ...

# %%
#Column Names 
df.columns
# Out:
# Index(['Unnamed: 0', 'Country Name', 'Year', 'GDP (current US$)',
#        'GDP, PPP (current international $)', 'GDP per capita (current US$)',
#        'GDP growth (annual %)', 'Imports of goods and services (% of GDP)',
#        'Exports of goods and services (% of GDP)',
#        'Central government debt, total (% of GDP)',
#        'Total reserves (includes gold, current US$)',
#        'Unemployment, total (% of total labor force) (modeled ILO estimate)',
#        'Inflation, consumer prices (annual %)',
#        'Personal remittances, received (% of GDP)', 'Population, total',
#        'Population growth (annual %)',
#        'Life expectancy at birth, total (years)',
#        'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)'],
#       dtype='object')

# %%
# Description of each column
df.describe()
# Out:
#        Unnamed: 0         Year  GDP (current US$)  \
# count   30.000000    30.000000       3.000000e+01
# mean    47.500000  2005.500000       1.320973e+13
# std      8.803408     8.803408       4.674607e+12
# min     33.000000  1991.000000       6.158129e+12
# 25%     40.250000  1998.250000       9.204907e+12
# 50%     47.500000  2005.500000       1.342739e+13
# 75%     54.750000  2012.750000       1.669589e+13
# max     62.000000  2020.000000       2.137257e+13
#
#        GDP, PPP (current international $)  GDP per capita (current US$)  \
# count                        3.000000e+01                     30.000000
# mean                         1.320973e+13                  43754.501616
# std                          4.674607e+12                  12355.698715
# min                          6.158129e+12                  24342.258905
# 25%                          9.204907e+12                  33269.105271
# 50%                          1.342739e+13                  45212.703974
# ...

# %%
# GDP histogram 
sns.histplot(x='GDP (current US$)', data=df, color = 'black')
# Out:
# <AxesSubplot:xlabel='GDP (current US$)', ylabel='Count'>

# %%
#Maximum range of GDP (current US$) is beltween .1 and 2.5

# %%
# GDP per capita histogram 
sns.histplot(x='GDP per capita (current US$)', data = df, color ='green')
# Out:
# <AxesSubplot:xlabel='GDP per capita (current US$)', ylabel='Count'>

# %%
#Between 25000 and 65000 current GDP per capita

# %%
# Histogram of centeral governemnt debt
sns.histplot(x= 'Central government debt, total (% of GDP)', data=df, color='red')
# Out:
# <AxesSubplot:xlabel='Central government debt, total (% of GDP)', ylabel='Count'>

# %%
#BOX Plot

# %%
sns.boxplot(x='Country Name', y = 'GDP (current US$)', data=df, color='brown')
# Out:
# <AxesSubplot:xlabel='Country Name', ylabel='GDP (current US$)'>

# %%
sns.boxplot(x= 'Country Name', y = 'Imports of goods and services (% of GDP)', data=df)
# Out:
# <AxesSubplot:xlabel='Country Name', ylabel='Imports of goods and services (% of GDP)'>

# %%
#Bi-variate plot

# %%
# GDP growth (annual %) vs population growth (annual %)
sns.scatterplot(x='Population growth (annual %)', y = 'GDP growth (annual %)', data=df)
# Out:
# <AxesSubplot:xlabel='Population growth (annual %)', ylabel='GDP growth (annual %)'>

# %%
# GDP (current US$) vs Exports of goods and services (% of GDP)
sns.scatterplot(x='Exports of goods and services (% of GDP)', y = 'GDP (current US$)', data=df,color='red')
# Out:
# <AxesSubplot:xlabel='Exports of goods and services (% of GDP)', ylabel='GDP (current US$)'>
